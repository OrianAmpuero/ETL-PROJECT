# %% [markdown]
# # DF WINE

# %% [markdown]
# ## Importaciones y carga de datos

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import requests as rq

import warnings
warnings.filterwarnings('ignore')                  # para quitar warnings

from pymongo import MongoClient
from sqlalchemy import create_engine

pd.set_option('display.max_columns', None)         # muestra todas las columnas del df.head()

# %%
df= pd.read_csv(r'C:\Users\Oriana Ampuero\ironhack\semana4\PROJECT-3\DATA\wines_SPA.csv')

df.head(15)
# Out:
#                  winery                            wine  year  rating  \
# 0         Teso La Monja                           Tinto  2013     4.9
# 1                Artadi                   Vina El Pison  2018     4.9
# 2          Vega Sicilia                           Unico  2009     4.8
# 3          Vega Sicilia                           Unico  1999     4.8
# 4          Vega Sicilia                           Unico  1996     4.8
# 5          Vega Sicilia                           Unico  1998     4.8
# 6          Vega Sicilia                           Unico  2010     4.8
# 7          Vega Sicilia                           Unico  1995     4.8
# 8          Vega Sicilia  Unico Reserva Especial Edicion  2015     4.8
# 9          Vega Sicilia                           Unico  2011     4.8
# 10         Vega Sicilia  Unico Reserva Especial Edicion  2016     4.8
# 11  Pago de Carraovejas                       El Anejon  2016     4.8
# 12         Vega Sicilia  Unico Reserva Especial Edicion  2018     4.8
# 13         Vega Sicilia                           Unico  1970     4.8
# 14          Toro Albala       Don PX Convento Seleccion  1946     4.8
#
#     num_reviews country            region   price                  type  body  \
# 0            58  Espana              Toro  995.00              Toro Red   5.0
# 1            31  Espana    Vino de Espana  313.50           Tempranillo   4.0
# 2          1793  Espana  Ribera del Duero  324.95  Ribera Del Duero Red   5.0
# 3          1705  Espana  Ribera del Duero  692.96  Ribera Del Duero Red   5.0
# 4          1309  Espana  Ribera del Duero  778.06  Ribera Del Duero Red   5.0
# 5          1209  Espana  Ribera del Duero  490.00  Ribera Del Duero Red   5.0
# 6          1201  Espana  Ribera del Duero  349.00  Ribera Del Duero Red   5.0
# 7           926  Espana  Ribera del Duero  810.89  Ribera Del Duero Red   5.0
# 8           643  Espana  Ribera del Duero  345.00  Ribera Del Duero Red   5.0
# 9           630  Espana  Ribera del Duero  315.00  Ribera Del Duero Red   5.0
# 10          591  Espana  Ribera del Duero  514.85  Ribera Del Duero Red   5.0
# 11          454  Espana  Ribera del Duero  105.15  Ribera Del Duero Red   5.0
# 12          438  Espana  Ribera del Duero  430.00  Ribera Del Duero Red   5.0
# 13          417  Espana  Ribera del Duero  925.00  Ribera Del Duero Red   5.0
# 14          398  Espana  Montilla-Moriles  350.00         Pedro Ximenez   5.0
#
#     acidity
# 0       3.0
# 1       2.0
# 2       3.0
# 3       3.0
# 4       3.0
# 5       3.0
# 6       3.0
# 7       3.0
# 8       3.0
# 9       3.0
# 10      3.0
# 11      3.0
# 12      3.0
# 13      3.0
# 14      1.0

# %% [markdown]
# ## Exploración

# %%
# dimensiones del dataframe

dim_original= df.shape

df.shape
# Out:
# (7500, 11)

# %%
# información del df

df.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7500 entries, 0 to 7499
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   winery       7500 non-null   object
#  1   wine         7500 non-null   object
#  2   year         7498 non-null   object
#  3   rating       7500 non-null   float64
#  4   num_reviews  7500 non-null   int64
#  5   country      7500 non-null   object
#  6   region       7500 non-null   object
#  7   price        7500 non-null   float64
#  8   type         6955 non-null   object
#  9   body         6331 non-null   float64
#  10  acidity      6331 non-null   float64
# dtypes: float64(4), int64(1), object(6)
# memory usage: 3.1 MB

# %%
# crear lista con nombres actuales de las columnas

name_columns= df.columns.values
name_columns
# Out:
# array(['winery', 'wine', 'year', 'rating', 'num_reviews', 'country',
#        'region', 'price', 'type', 'body', 'acidity'], dtype=object)

# %%
# valores únicos en la columna 

df.namecolumn.unique()
